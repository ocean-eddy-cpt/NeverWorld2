# %%
from netCDF4 import Dataset
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import xarray as xr
from xgcm import Grid
import numpy as np
import cmocean
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Baseline directories (using hmix=5 as the baseline case; also have hmix=20):
#
# 1/4 degree:  /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.25deg_N15_baseline_hmix5/    <br />
# 1/8 degree:  /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.125deg_N15_baseline_hmix5/   <br />
# 1/16 degree: /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.0625deg_N15_baseline_hmix5/  <br />
# 1/32 degree: /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.03125deg_N15_baseline_hmix5  <br />

# %% [markdown]
# ### Reading in data for hmix=5:

# %%
#1/4 degree resolution, surface diagnostics are for uppermost 5 meters.
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.25deg_N15_baseline_hmix5/
fs1 = xr.open_dataset('static.nc', decode_times=False)
os1 = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc'], decode_times=False)

#1/8 degree resolution, surface diagnostics are for uppermost 5 meters.
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.125deg_N15_baseline_hmix5/
fs2 = xr.open_dataset('static.nc', decode_times=False)
os2 = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc'], decode_times=False)

#1/16 degree resolution, surface diagnostics are for uppermost 5 meters.
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.0625deg_N15_baseline_hmix5/
fs3 = xr.open_dataset('static.nc', decode_times=False)
os3 = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc','sub03/ocean.stats.nc','sub04/ocean.stats.nc',
                         'sub05/ocean.stats.nc'], decode_times=False)

#1/32 degree resolution, surface diagnostics are for uppermost 5 meters.
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.03125deg_N15_baseline_hmix5
fs4 = xr.open_dataset('static.nc', decode_times=False)

os4 = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc','sub03/ocean.stats.nc','sub04/ocean.stats.nc',
                        'sub05/ocean.stats.nc','sub06/ocean.stats.nc','sub07/ocean.stats.nc','sub08/ocean.stats.nc',
                        'sub09/ocean.stats.nc','sub10/ocean.stats.nc','sub11/ocean.stats.nc','sub12/ocean.stats.nc',
                        'sub13/ocean.stats.nc','sub14/ocean.stats.nc','sub15/ocean.stats.nc','sub16/ocean.stats.nc',
                        'sub17/ocean.stats.nc','sub18/ocean.stats.nc','sub19/ocean.stats.nc','sub20/ocean.stats.nc'], decode_times=False)

# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/
# Out:
# /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.25deg_N15_baseline_hmix5
# /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.125deg_N15_baseline_hmix5
# /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.0625deg_N15_baseline_hmix5
# /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.03125deg_N15_baseline_hmix5
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis

# %% [markdown]
# ### Reading in data for hmix=20:

# %%
# #1/4 degree resolution, surface diagnostics are for uppermost 5 meters.
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.25deg_N15_baseline_hmix20/
# fs1 = xr.open_dataset('static.nc', decode_times=False)
# os1 = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc','sub03/ocean.stats.nc'], decode_times=False)

# #1/8 degree resolution, surface diagnostics are for uppermost 5 meters.
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.125deg_N15_baseline_hmix20/
# fs2 = xr.open_dataset('static.nc', decode_times=False)
# os2 = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc','sub03/ocean.stats.nc'], decode_times=False)

# #1/16 degree resolution, surface diagnostics are for uppermost 5 meters.
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.0625deg_N15_baseline_hmix20/
# fs3 = xr.open_dataset('static.nc', decode_times=False)
# os3 = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc','sub03/ocean.stats.nc','sub04/ocean.stats.nc',
#                         'sub05/ocean.stats.nc','sub06/ocean.stats.nc','sub07/ocean.stats.nc'], decode_times=False)

# #1/32 degree resolution, surface diagnostics are for uppermost 5 meters.
# %cd /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.03125deg_N15_baseline_hmix20/
# fs4 = xr.open_dataset('static.nc', decode_times=False)
# os4 = xr.open_mfdataset(['sub01/ocean.stats.nc','sub02/ocean.stats.nc','sub03/ocean.stats.nc','sub04/ocean.stats.nc',
#                         'sub05/ocean.stats.nc','sub06/ocean.stats.nc','sub07/ocean.stats.nc','sub08/ocean.stats.nc',
#                         'sub09/ocean.stats.nc','sub10/ocean.stats.nc','sub11/ocean.stats.nc','sub12/ocean.stats.nc',
#                         'sub13/ocean.stats.nc','sub14/ocean.stats.nc','sub15/ocean.stats.nc','sub16/ocean.stats.nc',
#                         'sub17/ocean.stats.nc','sub18/ocean.stats.nc','sub19/ocean.stats.nc','sub20/ocean.stats.nc',
#                         'sub21/ocean.stats.nc'], decode_times=False)

# %cd /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis/
# Out:
# /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.25deg_N15_baseline_hmix20
# /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.125deg_N15_baseline_hmix20
# /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.0625deg_N15_baseline_hmix20
# /glade/p/univ/unyu0004/gmarques/NeverWorld2/baselines/nw2_0.03125deg_N15_baseline_hmix20
# /glade/p/univ/unyu0004/eyankovsky/NeverWorld_analysis

# %%
plt.figure(figsize=(10,15))
plt.subplot(3,1,1)
    
plt.plot(os1.Time,os1.En); plt.plot(os2.Time,os2.En); plt.plot(os3.Time,os3.En); plt.plot(os4.Time,os4.En)
#plt.xlim((0,30000))
plt.ylabel('total energy (Joules)') 
#plt.gca().legend(('1/4 degree, DT = 1200', '1/8 degree, DT = 600 -> DT = 450', '1/16 degree, DT = 225 -> 200 -> 160', '1/32 degree spin-up, DT = 60'))

plt.subplot(3,1,2)
plt.plot(os1.Time,os1.KE.sum(axis=1)); plt.plot(os2.Time,os2.KE.sum(axis=1)), plt.plot(os3.Time,os3.KE.sum(axis=1)); plt.plot(os4.Time,os4.KE.sum(axis=1))
plt.ylabel('KE (Joules)')
    
plt.subplot(3,1,3)
plt.plot(os1.Time,os1.APE.sum(axis=1)); plt.plot(os2.Time,os2.APE.sum(axis=1)); plt.plot(os3.Time,os3.APE.sum(axis=1)); plt.plot(os4.Time,os4.APE.sum(axis=1))
plt.ylabel('APE (Joules)')
plt.xlabel('Time (days)')

#plt.savefig('Energy_quarter_eighth_sixteenth_degree.png', dpi=200,bbox_inches='tight',pad_inches=0)
# DT is the time-step (in seconds) used to run the model
# The slight kink on the 1/8 degree run at 14500 days is because the time-step needed to be reduced because of high CFL with DT = 600 and needed a restart with DT = 450.
# Out:
# Text(0.5, 0, 'Time (days)')

# %% [markdown]
# ## Time monotonically increases in each run!

# %%
fig=plt.figure(figsize=(8,8),dpi=100)
plt.subplot(2,2,1)
plt.plot(np.linspace(0,os1.Time.shape[0],os1.Time.shape[0]),os1.Time)
plt.xlabel('index',fontsize=14)
plt.ylabel('time (days)',fontsize=14)
plt.title('1/4 deg.')
plt.subplot(2,2,2)
plt.plot(np.linspace(0,os2.Time.shape[0],os2.Time.shape[0]),os2.Time)
plt.xlabel('index',fontsize=14)
plt.title('1/8 deg.')

plt.subplot(2,2,3)
plt.plot(np.linspace(0,os3.Time.shape[0],os3.Time.shape[0]),os3.Time)
plt.xlabel('index',fontsize=14)
plt.ylabel('time (days)',fontsize=14)
plt.title('1/16 deg.')

plt.subplot(2,2,4)
plt.plot(np.linspace(0,os4.Time.shape[0],os4.Time.shape[0]),os4.Time)
plt.xlabel('index',fontsize=14)
plt.title('1/32 deg.')

fig.tight_layout()

# %% [markdown]
# ## Shifting forward each of the higher-resolution runs to start at the time that the previous run ended.

# %%
time1=os1.Time
time2=time1[-1]+(os2.Time)
time3=time2[-1]+(os3.Time)
time4=time3[-1]+(os4.Time)

# %%
plt.figure(figsize=(8,10),dpi=300)


time_0   = 0
time_lim = 45000

plt.subplot(3,1,1)
plt.plot(time1,os1.En/1000,label='$1/4^\circ$',color=[0,0,0.5])
plt.plot(time2,os2.En/1000,label='$1/8^\circ$',color=[1,.6,0]) #[0:1002]
plt.plot(time3,os3.En/1000,label='$1/16^\circ$',color='c')
plt.plot(time4,os4.En/1000,label='$1/32^\circ$',color='m')
plt.xlim((time_0,time_lim)); 
plt.ylim((0e20,1.2e17))
plt.ylabel('Total Energy ($m^5 s^{-2}$)',fontsize=14) 
plt.legend(fontsize=12)
plt.grid()

plt.subplot(3,1,2)
#plt.plot([time_0,time_lim],[os1.KE[-100:].sum(axis=1).mean('Time'),os1.KE[-100:].sum(axis=1).mean('Time')],'--',color=[0,0,0.5])
#plt.plot([time_0,time_lim],[os2.KE[-100:].sum(axis=1).mean('Time'),os2.KE[-100:].sum(axis=1).mean('Time')],'--',color=[1,.6,0]) #[0:1002]
#plt.plot([time_0,time_lim],[os3.KE[-100:].sum(axis=1).mean('Time'),os3.KE[-100:].sum(axis=1).mean('Time')],'--',color='c')
#plt.plot([time_0,time_lim],[os4.KE[-100:].sum(axis=1).mean('Time'),os4.KE[-100:].sum(axis=1).mean('Time')],'--',color='m')

plt.plot(time1,os1.KE.sum(axis=1)/1000,color=[0,0,0.5])
plt.plot(time2[0:],os2.KE.sum(axis=1)[0:]/1000,color=[1,.6,0])
plt.plot(time3[0:],os3.KE.sum(axis=1)[0:]/1000,color='c')
plt.plot(time4[0:],os4.KE.sum(axis=1)[0:]/1000,color='m')
plt.xlim((time_0,time_lim)); 
plt.ylim((0,3e15)); 
plt.ylabel('KE ($m^5 s^{-2}$)',fontsize=14)
plt.grid()

plt.subplot(3,1,3)
#plt.plot([time_0,time_lim],[os1.APE[-100:].sum(axis=1).mean('Time'),os1.APE[-100:].sum(axis=1).mean('Time')],'--',color=[0,0,0.5])
#plt.plot([time_0,time_lim],[os2.APE[-100:].sum(axis=1).mean('Time'),os2.APE[-100:].sum(axis=1).mean('Time')],'--',color=[1,.6,0]) #[0:1002]
#plt.plot([time_0,time_lim],[os3.APE[-100:].sum(axis=1).mean('Time'),os3.APE[-100:].sum(axis=1).mean('Time')],'--',color='c')
#plt.plot([time_0,time_lim],[os4.APE[-100:].sum(axis=1).mean('Time'),os4.APE[-100:].sum(axis=1).mean('Time')],'--',color='m')
#
plt.plot(time1,os1.APE.sum(axis=1)/1000,color=[0,0,0.5])
plt.plot(time2,os2.APE.sum(axis=1)/1000,color=[1,.6,0])
plt.plot(time3,os3.APE.sum(axis=1)/1000,color='c')
plt.plot(time4,os4.APE.sum(axis=1)/1000,color='m')
plt.xlim((time_0,time_lim)); 
plt.ylim((0.e20,1.2e17))
plt.ylabel('APE ($m^5s^{-2}$)',fontsize=14)
plt.xlabel('Time (days)')
plt.grid()
