# %% [markdown]
# # Code to evaluate EKE in NeverWorld2 and compare results from different configurations

# %%
from netCDF4 import Dataset
import numpy as np
import matplotlib
# matplotlib.rcParams['font.sans-serif'] = "Latin Modern Roman"
matplotlib.rcParams['font.family'] = "serif"
matplotlib.rcParams['mathtext.fontset'] = "cm"
import matplotlib.pyplot as plt
plt.rcParams['mathtext.fontset'] = 'dejavuserif'
import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)
import xarray as xr
from xgcm import Grid
import numpy as np
import cmocean
import datetime
import pandas as pd

# %%
import matplotlib.colors as colors

class MidpointNormalize(colors.Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y))

# %% [markdown]
# ## Comparison of total energy

# %%
run = [13,10,9,11,12]

plt.figure(figsize=(12,6))

for i in range(len(run)):
    os = xr.open_dataset('run%i/ocean.stats.nc' % run[i], decode_times=False)
    plt.plot(os.Time,os.En)
    
plt.xlabel('time (days)')
plt.ylabel('total energy (Joules)')
plt.gca().legend(('SARDOUNY75_ENERGY','SARDOUNY75_ENSTRO','ARAKAWA_HSU90','ARAKAWA_LAMB81','ARAKAWA_LAMB_BLEND'))

plt.savefig('energy_vs_time.png', dpi=200,bbox_inches='tight',pad_inches=0)

# %% [markdown]
# ## CFL check for the failed run relative to a reference case

# %%
# for the failed run 
failed_run = [13,10,9]

plt.figure(figsize=(12,8))

for i in range(len(failed_run)):
    os = xr.open_dataset('run%i/ocean.stats.nc' % failed_run[i], decode_times=False)
    plt.subplot(2,2,1)
    plt.hist(os.max_CFL_lin, bins='auto', density=True)
    plt.title('Maximum finite-difference CFL')

    plt.subplot(2,2,2)
    plt.hist(os.max_CFL_trans, bins='auto', density=True)
    plt.title('Maximum finite-volume CFL')

    plt.subplot(2,2,3)
    plt.plot(os.Time,os.max_CFL_lin)
    plt.xlabel('time (days)')

    plt.subplot(2,2,4)
    plt.plot(os.Time,os.max_CFL_trans)
    plt.xlabel('time (days)')

plt.gca().legend(('SARDOUNY75_ENERGY','SARDOUNY75_ENSTRO','ARAKAWA_HSU90'))
plt.savefig('CFL_SARDOUNY75_ENSTRO.png', dpi=200,bbox_inches='tight',pad_inches=0)
# Out:
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if sys.path[0] == '':
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   app.launch_new_instance()
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if sys.path[0] == '':
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/ipykernel_launcher.py:16: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   app.launch_new_instance()
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/ipykernel_launcher.py:20: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# ## Comparison of velocities (effective and diagnosed)

# %%
tau = 5*86400 # seconds
end_time = 30000
start_time = end_time - tau/86400
run = 13

# %%
av = xr.open_dataset('run%i/averages_000%i.nc' % (run, end_time-500+2), decode_times=False)
st = xr.open_dataset('run%i/static.nc' % run, decode_times=False)

# %%
def interp_h_to_u(h):
    n,layers,ly,lx = h.shape
    h_at_u = np.zeros((n,layers,ly,lx+1))
    h_at_u[:,:,:,1:-1] = (h[:,:,:,:-1] + h[:,:,:,1:])/2
    h_at_u[:,:,:,0] = (h[:,:,:,0] + h[:,:,:,-1])/2 # periodic
    h_at_u[:,:,:,-1] = (h[:,:,:,0] + h[:,:,:,-1])/2 # periodic
    
    return h_at_u
    
def interp_h_to_v(h):
    n,layers,ly,lx = h.shape
    h_at_v = np.zeros((n,layers,ly+1,lx))
    h_at_v[:,:,1:-1,:] = (h[:,:,:-1,:] + h[:,:,1:,:])/2
    h_at_v[:,:,0,:] = h[:,:,0,:] # non-periodic
    h_at_v[:,:,-1,:] = h[:,:,-1,:] # non-periodic
    
    return h_at_v

h_at_u = interp_h_to_u(av.h.values.astype(float)) # m
u_eff = (av.uh.astype(float))/(h_at_u*st.dyCu.values.astype(float) + 1e-20) # m/s 
u_eff = u_eff.sel(time=slice(start_time,end_time)).values.astype(float)
u_diag = av.u.sel(time=slice(start_time,end_time)).values.astype(float)

h_at_v = interp_h_to_v(av.h.values.astype(float))
v_eff = (av.vh.astype(float))/(h_at_v*st.dxCv.values.astype(float) + 1e-20) # m/s 
v_eff = v_eff.sel(time=slice(start_time,end_time)).values.astype(float)
v_diag = av.v.sel(time=slice(start_time,end_time)).values.astype(float)

# %%
print(u_diag.shape,u_eff.shape)
plt.figure(figsize=(15,7))
plt.subplot(2,2,1)
plt.scatter(u_diag,u_eff)
plt.plot([np.nanmin(u_diag),np.nanmax(u_diag)],[np.nanmin(u_diag),np.nanmax(u_diag)],'k-')
plt.xlabel('Model diagnosed u')
plt.ylabel('Effective u')
plt.grid()

plt.subplot(2,2,2)
plt.scatter(v_diag,v_eff)
plt.plot([np.nanmin(v_diag),np.nanmax(v_diag)],[np.nanmin(v_diag),np.nanmax(v_diag)],'k-')
plt.xlabel('Model diagnosed v')
plt.ylabel('Effective v')
plt.grid()

plt.savefig('scatter_velocities_start_time_%i_days_end_time_%i_days.png' % (start_time,end_time), dpi=200,bbox_inches='tight',pad_inches=0)

plt.show()
# Out:
# (1, 15, 560, 241) (1, 15, 560, 241)

# %% [markdown]
# # Reynolds averaged EKE

# %%
tau = 500*86400 # seconds
end_time = 30000
start_time = end_time - tau/86400
run = 13

av = xr.open_dataset('run%i/averages_000%i.nc' % (run, end_time-500+2), decode_times=False)
lm = xr.open_dataset('run%i/longmean_00028250.nc' % run, decode_times=False)
st = xr.open_dataset('run%i/static.nc' % run, decode_times=False)

# %%
area_u = st.area_u.values.astype(float) # m^2
area_v = st.area_v.values.astype(float) # m^2
area_t = st.area_t.values.astype(float) # m^2
H = st.depth_ocean.values.astype(float) # m

# %%
h_temp = av.h.sel(time=slice(start_time,end_time)).values.astype(float)
u_temp = av.u.sel(time=slice(start_time,end_time)).values.astype(float)
v_temp = av.v.sel(time=slice(start_time,end_time)).values.astype(float)
TKE_temp = lm.KE.sel(time=slice(start_time,end_time)).values.astype(float)

# These are tau day averages of the 5-day averages
h_fine = h_temp.mean(axis=0) # m
TKE = TKE_temp.mean(axis=0) # m^2/s^2
u_fine = u_temp.mean(axis=0) # m/s
v_fine = v_temp.mean(axis=0) # m/s

# %%
grid = Grid(av, coords={'X': {'center': 'xh', 'outer': 'xq'},
                        'Y': {'center': 'yh', 'outer': 'yq'},
                        'Z': {'center': 'z_l', 'outer': 'z_i'} }, periodic=['X'])


def interp_u2_to_center(u):
    layers,ly,lx_p_1 = u.shape
    lx = lx_p_1 - 1
    u_center = np.zeros((layers,ly,lx))
    u_center[:,:,:] = (u[:,:,:-1] + u[:,:,1:])/2
    u_center[:,:,0] = (u[:,:,0] + u[:,:,-1])/2 # periodic
    u_center[:,:,-1] = (u[:,:,0] + u[:,:,-1])/2 # periodic
    
    return u_center
    
def interp_v2_to_center(v):
    layers,ly_p_1,lx = v.shape
    ly = ly_p_1 - 1
    v_center = np.zeros((layers,ly,lx))
    v_center[:,:,:] = (v[:,:-1,:] + v[:,1:,:])/2
    
    return v_center

u2_temp = u_fine*u_fine*area_u
v2_temp = v_fine*v_fine*area_v

MKE = 0.5*(interp_u2_to_center(u2_temp) + interp_v2_to_center(v2_temp))/area_t

# %%
MKE.shape
# Out:
# (15, 560, 240)

# %%
EKE = TKE - MKE
xh = st.xh
yh = st.yh

# %%
plt.figure(figsize=(12,16))

l = 0

# vmin = np.nanmin(EKE[l])
# vmax = np.nanmax(TKE[l])

plt.subplot(3,3,1)
plt.pcolormesh(xh,yh,TKE[l], cmap=cmocean.cm.matter_r)
plt.ylabel(r'layer %i' %l)
plt.title(r'TKE = $\langle \mathbf{u} \cdot \mathbf{u} \rangle/2$')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,2)
plt.pcolormesh(xh,yh,MKE[l], cmap=cmocean.cm.matter_r)
plt.title(r'MKE = $\langle \mathbf{u} \rangle\cdot \langle  \mathbf{u} \rangle/2$')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,3)
plt.pcolormesh(xh,yh,EKE[l], cmap=cmocean.cm.matter_r)
plt.title('EKE')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

l = 6

# vmin = np.nanmin(EKE[l])
# vmax = np.nanmax(TKE[l])

plt.subplot(3,3,4)
plt.pcolormesh(xh,yh,TKE[l], cmap=cmocean.cm.matter_r)
plt.ylabel(r'layer %i' %l)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,5)
plt.pcolormesh(xh,yh,MKE[l], cmap=cmocean.cm.matter_r)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,6)
plt.pcolormesh(xh,yh,EKE[l], cmap=cmocean.cm.matter_r)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

l = 10

# vmin = np.nanmin(EKE[l])
# vmax = np.nanmax(TKE[l])

plt.subplot(3,3,7)
plt.pcolormesh(xh,yh,TKE[l], cmap=cmocean.cm.matter_r)
plt.ylabel(r'layer %i' %l)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,8)
plt.pcolormesh(xh,yh,MKE[l], cmap=cmocean.cm.matter_r)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,9)
plt.pcolormesh(xh,yh,EKE[l], cmap=cmocean.cm.matter_r)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()


plt.savefig('Energy_start_time_%i_days_tau_%i_days.png' % (start_time,tau/86400), dpi=200,bbox_inches='tight',pad_inches=0)

# %%
EKE_depth_averaged_temp = EKE*h_fine/(H)

EKE_depth_averaged = EKE_depth_averaged_temp.sum(axis=0)

plt.figure(figsize=(4,6))

plt.pcolormesh(xh,yh,EKE_depth_averaged, cmap=cmocean.cm.matter_r)
plt.ylabel('longitude')
plt.ylabel('latitude')
plt.title('Thickness-weighted depth-averaged EKE')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.savefig('EKE_start_time_%i_days_tau_%i_days.png' % (start_time,tau/86400), dpi=200,bbox_inches='tight',pad_inches=0)

# %%
EKE_depth_averaged.shape
# Out:
# (560, 240)

# %% [markdown]
# # Coarsening

# %%
tau = 5*86400 # seconds
end_time = 30000
start_time = end_time - tau/86400
run = 13
coarsen = 2

av = xr.open_dataset('run%i/averages_000%i.nc' % (run, end_time-500+2), decode_times=False)
st = xr.open_dataset('run%i/static.nc' % run, decode_times=False)

# %%
xh_c = st.xh.values.reshape(-1,coarsen).mean(axis=1)
yh_c = st.yh.values.reshape(-1,coarsen).mean(axis=1)

# %%
# These are the raw 5-day average data 
h_fine = av.h.sel(time=slice(start_time,end_time)).values.astype(float)
u_fine = av.u.sel(time=slice(start_time,end_time)).values.astype(float)
v_fine = av.v.sel(time=slice(start_time,end_time)).values.astype(float)

# %%
def coarsen_KE(TKE):
    n,l,ly,lx = TKE.shape 
    TKE_c = np.zeros((n,l,ly//coarsen,lx//coarsen))
    for j in range(coarsen):
        for i in range(coarsen):
            TKE_c[:,:,:,:] = TKE_c[:,:,:,:] + TKE[:,:,j::coarsen,i::coarsen]
    
    return TKE_c/coarsen**2

# %%
def coarsen_u(u_fine):
    """It returns the mean over j"""
    n,l,ly,lx_p_1 = u_fine.shape 
    lx = lx_p_1 - 1
    uc_coarse = np.zeros((n,l,ly//coarsen,lx//coarsen+1))
    
    # Coarsening uc to uc_coarse
    for j in range(coarsen):
        uc_coarse[:,:,:,:] = uc_coarse[:,:,:,:] + u_fine[:,:,j::coarsen,::coarsen]
    
    return uc_coarse/coarsen

def coarsen_v(v_fine):
    n,l,ly_p_1,lx = v_fine.shape 
    ly = ly_p_1 - 1
    vc_coarse = np.zeros((n,l,ly//coarsen+1,lx//coarsen))
    
    # Coarsening uc to uc_coarse
    for i in range(coarsen):
        vc_coarse[:,:,:,:] = vc_coarse[:,:,:,:] + v_fine[:,:,::coarsen,i::coarsen]
    
    return vc_coarse/coarsen

def project_u_to_fine(u_coarse):
    n,l,ly_coarsen,lx_coarsen_p_1 = u_coarse.shape 
    ly,lx = coarsen*ly_coarsen,coarsen*(lx_coarsen_p_1-1)
    uc_fine = np.zeros((n,l,ly,lx//coarsen+1))
    
    # Projecting onto the fine grid 
    for j in range(coarsen):
        uc_fine[:,:,j::coarsen,:] = u_coarse[:,:,:,:]
        
    return uc_fine

def project_v_to_fine(v_coarse):
    n,l,ly_coarsen_p_1,lx_coarsen = v_coarse.shape 
    ly,lx = coarsen*(ly_coarsen_p_1-1),coarsen*lx_coarsen
    vc_fine = np.zeros((n,l,ly//coarsen+1,lx))
    
    # Projecting onto the fine grid 
    for i in range(coarsen):
        vc_fine[:,:,:,i::coarsen] = v_coarse[:,:,:,:]
        
    return vc_fine

# %%
def interp_area_to_u(area_c):
    ly,lx = area_c.shape
    area_c_u = np.zeros((ly,lx+1))
    area_c_u[:,1:-1] = (area_c[:,:-1] + area_c[:,1:])/2
    area_c_u[:,0] = (area_c[:,0] + area_c[:,-1])/2 # periodic
    area_c_u[:,-1] = (area_c[:,0] + area_c[:,-1])/2 # periodic
    
    return area_c_u
    
def interp_area_to_v(area_c):
    ly,lx = area_c.shape
    area_c_v = np.zeros((ly+1,lx))
    area_c_v[1:-1,:] = (area_c[:-1,:] + area_c[1:,:])/2
    area_c_v[0,:] = area_c[0,:] # non-periodic
    area_c_v[-1,:] = area_c[-1,:] # non-periodic
    
    return area_c_v

def interp_u2_to_center(u):
    n,layers,ly,lx_p_1 = u.shape
    lx = lx_p_1 - 1
    u_center = np.zeros((n,layers,ly,lx))
    u_center[:,:,:,:] = (u[:,:,:,:-1] + u[:,:,:,1:])/2
    u_center[:,:,:,0] = (u[:,:,:,0] + u[:,:,:,-1])/2 # periodic
    u_center[:,:,:,-1] = (u[:,:,:,0] + u[:,:,:,-1])/2 # periodic
    
    return u_center
    
def interp_v2_to_center(v):
    n,layers,ly_p_1,lx = v.shape
    ly = ly_p_1 - 1
    v_center = np.zeros((n,layers,ly,lx))
    v_center[:,:,:,:] = (v[:,:,:-1,:] + v[:,:,1:,:])/2
    
    return v_center

# %%
n,l,ly,lx = h_fine.shape

area_c = area_t.reshape((ly//coarsen,coarsen,lx//coarsen,coarsen)).sum(axis=-1).sum(axis=1) # m^2

u2_temp = u_fine*u_fine*area_u
v2_temp = v_fine*v_fine*area_v

TKE_temp = 0.5*(interp_u2_to_center(u2_temp) + interp_v2_to_center(v2_temp))/area_t

TKE_c = coarsen_KE(TKE_temp).mean(axis=0)
print(TKE_c.shape)

area_u_c = interp_area_to_u(area_c) # m^2
area_v_c = interp_area_to_v(area_c) # m^2

uc_coarse = coarsen_u(u_fine)
vc_coarse = coarsen_v(v_fine)

u2_temp = uc_coarse*uc_coarse*area_u_c
v2_temp = vc_coarse*vc_coarse*area_v_c

MKE_temp = 0.5*(interp_u2_to_center(u2_temp) + interp_v2_to_center(v2_temp))/area_c
MKE_c = MKE_temp.mean(axis=0)

print(MKE_c.shape)
# Out:
# (15, 280, 120)
# (15, 280, 120)

# %%
EKE_c = TKE_c - MKE_c

# %%
plt.figure(figsize=(12,16))

l = 0

# vmin = np.nanmin(EKE[l])
# vmax = np.nanmax(TKE[l])

plt.subplot(3,3,1)
plt.pcolormesh(xh_c,yh_c,TKE_c[l], cmap=cmocean.cm.matter_r)
plt.ylabel(r'layer %i' %l)
plt.title(r'TKE = $\langle \mathbf{u} \cdot \mathbf{u} \rangle/2$')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,2)
plt.pcolormesh(xh_c,yh_c,MKE_c[l], cmap=cmocean.cm.matter_r)
plt.title(r'MKE = $\langle \mathbf{u}_C \cdot  \mathbf{u}_C \rangle/2$')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,3)
plt.pcolormesh(xh_c,yh_c,EKE_c[l], cmap=cmocean.cm.matter_r)
plt.title('EKE')
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

l = 6

# vmin = np.nanmin(EKE[l])
# vmax = np.nanmax(TKE[l])

plt.subplot(3,3,4)
plt.pcolormesh(xh_c,yh_c,TKE_c[l], cmap=cmocean.cm.matter_r)
plt.ylabel(r'layer %i' %l)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,5)
plt.pcolormesh(xh_c,yh_c,MKE_c[l], cmap=cmocean.cm.matter_r)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,6)
plt.pcolormesh(xh_c,yh_c,EKE_c[l], cmap=cmocean.cm.matter_r)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

l = 10

# vmin = np.nanmin(EKE[l])
# vmax = np.nanmax(TKE[l])

plt.subplot(3,3,7)
plt.pcolormesh(xh_c,yh_c,TKE_c[l], cmap=cmocean.cm.matter_r)
plt.ylabel(r'layer %i' %l)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,8)
plt.pcolormesh(xh_c,yh_c,MKE_c[l], cmap=cmocean.cm.matter_r)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()

plt.subplot(3,3,9)
plt.pcolormesh(xh_c,yh_c,EKE_c[l], cmap=cmocean.cm.matter_r)
plt.gca().set_aspect('equal', adjustable='box')
plt.axis([xh.min(), xh.max(), yh.min(), yh.max()])
plt.colorbar()


plt.savefig('Energy_coarsen_%i_start_time_%i_days_tau_%i_days.png' % (coarsen,start_time,tau/86400), dpi=200,bbox_inches='tight',pad_inches=0)

# %% [markdown]
# ## SSH videos

# %%
st = xr.open_dataset('run13/static.nc', decode_times=False)
xh = st.xh.values
yh = st.yh.values

grid = Grid(st, coords={'X': {'center': 'xh', 'outer': 'xq'},
                        'Y': {'center': 'yh', 'outer': 'yq'},
                        'Z': {'center': 'z_l', 'outer': 'z_i'} }, periodic=['X'])

run = [13,9,11,12]
ci = np.arange(-3.5,1.5,0.2)
plots = len(run)

end_time = 250-2000
while end_time < 27000:
    end_time = end_time + 2000
    print(end_time)
    filename = 'run13/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av1 = xr.open_dataset(filename, decode_times=False)
    filename = 'run9/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av2 = xr.open_dataset(filename, decode_times=False)
    filename = 'run11/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av3 = xr.open_dataset(filename, decode_times=False)
    filename = 'run12/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av4 = xr.open_dataset(filename, decode_times=False)
    e1 = av1.e.values[:,0]
    e2 = av2.e.values[:,0]
    e3 = av3.e.values[:,0]
    e4 = av4.e.values[:,0]
    time = av1.time
    for i in range(len(time)):
        plt.figure(figsize=(12,4))
        plt.suptitle('Time = %.1f days' %time[i])
        plt.subplot(1,plots,1)
        plt.contourf(xh,yh,e1[i], cmap=cmocean.cm.deep_r,levels = ci)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.ylabel('latitude')
        plt.title('SARDOUNY75_ENERGY')
        plt.subplot(1,plots,2)
        plt.contourf(xh,yh,e2[i], cmap=cmocean.cm.deep_r,levels = ci)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.title('ARAKAWA_HSU90')
        plt.subplot(1,plots,3)
        plt.contourf(xh,yh,e3[i], cmap=cmocean.cm.deep_r,levels = ci)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.title('ARAKAWA_LAMB81')
        plt.subplot(1,plots,4)
        plt.contourf(xh,yh,e4[i], cmap=cmocean.cm.deep_r,levels = ci)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.title('ARAKAWA_LAMB_BLEND')
        plt.colorbar()
        save_name = 'SSH/fig_'+'{0:06}'.format(int(time[i]))+ '.png'
        plt.savefig(save_name, dpi=200,bbox_inches='tight',pad_inches=0)
        plt.close()
# Out:
# 250
# 2250
# 4250
# 6250
# 8250
# 10250
# 12250
# 14250
# 16250
# 18250
# 20250
# 22250
# 24250
# 26250
# 28250

# %% [markdown]
# ## Okubo-Weiss parameter

# %%
st = xr.open_dataset('run13/static.nc', decode_times=False)
xh = st.xh.values
yh = st.yh.values
xq = st.xq.values
yq = st.yq.values

grid = Grid(st, coords={'X': {'center': 'xh', 'outer': 'xq'},
                        'Y': {'center': 'yh', 'outer': 'yq'},
                        'Z': {'center': 'z_l', 'outer': 'z_i'} }, periodic=['X'])

run = [13,9,11,12]
plots = len(run)

filename = 'run13/averages_00000002.nc'
av1 = xr.open_dataset(filename, decode_times=False)
ob1 = grid.interp(grid.interp(av1.NoSt2, axis='X',boundary='fill'), axis='Y',boundary='fill').values[:,0] + av1.ShSt2.values[:,0] -  av1.RV2.values[:,0]
vmin_i = np.nanmin(ob1)
vmax_i = np.nanmax(ob1)

filename = 'run13/averages_00029502.nc'
av1 = xr.open_dataset(filename, decode_times=False)
ob1 = grid.interp(grid.interp(av1.NoSt2, axis='X',boundary='fill'), axis='Y',boundary='fill').values[:,0] + av1.ShSt2.values[:,0] -  av1.RV2.values[:,0]
vmin_f = np.nanmin(ob1)
vmax_f = np.nanmax(ob1)

# %%
layer = 0
time = 0

RV = av1.RV.values[time,layer].astype(float)
RV2 = av1.RV2.values[time,layer].astype(float)/86400
NoSt2 = av1.NoSt2.values[time,layer].astype(float)/86400
ShSt2 = av1.ShSt2.values[time,layer].astype(float)/86400
NoSt2 = grid.interp(grid.interp(av1.NoSt2, axis='X',boundary='fill'), axis='Y',boundary='fill').values[time,layer].astype(float)/86400
OB = NoSt2 + ShSt2 - RV2

plt.figure(figsize=(25,8))
plt.subplot(1,5,1)
plt.pcolormesh(xq,yq,RV,norm=MidpointNormalize(midpoint=0.),cmap='RdBu')
plt.gca().set_aspect('equal', adjustable='box')
plt.title(r'Relative vorticity: $\zeta$')
plt.colorbar()

plt.subplot(1,5,2)
plt.pcolormesh(xq,yq,(RV2), norm=colors.LogNorm(vmin=8e-15, vmax=np.nanmax(RV2)), cmap=cmocean.cm.deep)
plt.gca().set_aspect('equal', adjustable='box')
plt.title(r'Enstrophy: $\zeta^2$')
plt.colorbar()

plt.subplot(1,5,3)
plt.pcolormesh(xq,yq,(ShSt2), norm=colors.LogNorm(vmin=8e-15, vmax=np.nanmax(ShSt2)), cmap=cmocean.cm.deep)
plt.gca().set_aspect('equal', adjustable='box')
plt.title(r'Shear stress$^2$: $s_s^2$')
plt.colorbar()

plt.subplot(1,5,4)
plt.pcolormesh(xq,yq,(NoSt2), norm=colors.LogNorm(vmin=8e-15, vmax=np.nanmax(NoSt2)), cmap=cmocean.cm.deep)
plt.gca().set_aspect('equal', adjustable='box')
plt.title(r'Normal stress$^2$: $s_n^2$')
plt.colorbar()

plt.subplot(1,5,5)
plt.pcolormesh(xq,yq,(OB),norm=colors.SymLogNorm(linthresh=np.nanmax(OB)/100000, linscale = np.nanmax(OB)/10000, vmin=np.nanmin(OB), vmax=np.nanmax(OB), base=10),cmap='RdBu')
# plt.pcolormesh(xq,yq,(OB),norm=MidpointNormalize(midpoint=0.),cmap='RdBu')
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Okubo-Weiss parameter: $s_n^2 + s_s^2 - \zeta^2$')
plt.colorbar()
save_name = 'Okubo_Weiss.png'
plt.savefig(save_name, dpi=200,bbox_inches='tight',pad_inches=0)
# Out:
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/pkg-library/20200417/lib/python3.7/site-packages/matplotlib/colors.py:1171: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %%
end_time = 29502-500
while end_time < 29502:
    end_time = end_time + 500
    print(end_time)
    filename = 'run13/averages_'+'{0:08}'.format(end_time)+ '.nc'
    av1 = xr.open_dataset(filename, decode_times=False)
    filename = 'run9/averages_'+'{0:08}'.format(end_time)+ '.nc'
    av2 = xr.open_dataset(filename, decode_times=False)
    filename = 'run11/averages_'+'{0:08}'.format(end_time)+ '.nc'
    av3 = xr.open_dataset(filename, decode_times=False)
    filename = 'run12/averages_'+'{0:08}'.format(end_time)+ '.nc'
    av4 = xr.open_dataset(filename, decode_times=False)
    ob1 = grid.interp(grid.interp(av1.NoSt2, axis='X',boundary='fill'), axis='Y',boundary='fill').values[:,0] + av1.ShSt2.values[:,0] -  av1.RV2.values[:,0]
    ob1 = ob1/86400
    ob2 = grid.interp(grid.interp(av2.NoSt2, axis='X',boundary='fill'), axis='Y',boundary='fill').values[:,0] + av2.ShSt2.values[:,0] -  av2.RV2.values[:,0]
    ob2 = ob2/86400
    ob3 = grid.interp(grid.interp(av3.NoSt2, axis='X',boundary='fill'), axis='Y',boundary='fill').values[:,0] + av3.ShSt2.values[:,0] -  av3.RV2.values[:,0]
    ob3 = ob3/86400
    ob4 = grid.interp(grid.interp(av4.NoSt2, axis='X',boundary='fill'), axis='Y',boundary='fill').values[:,0] + av4.ShSt2.values[:,0] -  av4.RV2.values[:,0]
    ob4 = ob4/86400
    time = av1.time
    for i in range(len(time)): 
        plt.figure(figsize=(12,4))
        plt.suptitle('Time = %.1f days' %time[i])
        plt.subplot(1,plots,1)
        plt.pcolormesh(xq,yq,ob1[i],norm=colors.SymLogNorm(linthresh=np.nanmax(ob1[i])/100000, linscale = np.nanmax(ob1[i])/10000, vmin=np.nanmin(ob1[i]), vmax=np.nanmax(ob1[i]), base=10), cmap='RdBu')
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.ylabel('latitude')
        plt.title('SARDOUNY75_ENERGY')
        plt.subplot(1,plots,2)
        plt.pcolormesh(xq,yq,ob2[i],norm=colors.SymLogNorm(linthresh=np.nanmax(ob1)/100000, linscale = np.nanmax(ob1)/10000, vmin=np.nanmin(ob1), vmax=np.nanmax(ob1), base=10), cmap='RdBu')
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.title('ARAKAWA_HSU90')
        plt.subplot(1,plots,3)
        plt.pcolormesh(xq,yq,ob3[i],norm=colors.SymLogNorm(linthresh=np.nanmax(ob1)/100000, linscale = np.nanmax(ob1)/10000, vmin=np.nanmin(ob1), vmax=np.nanmax(ob1), base=10), cmap='RdBu')
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.title('ARAKAWA_LAMB81')
        plt.subplot(1,plots,4)
        plt.pcolormesh(xq,yq,ob4[i],norm=colors.SymLogNorm(linthresh=np.nanmax(ob1)/100000, linscale = np.nanmax(ob1)/10000, vmin=np.nanmin(ob1), vmax=np.nanmax(ob1), base=10), cmap='RdBu')
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.title('ARAKAWA_LAMB_BLEND')
        plt.colorbar()
        save_name = 'Okubo_Weiss/fig_'+'{0:06}'.format(int(time[i]))+ '.png'
        plt.savefig(save_name, dpi=200,bbox_inches='tight',pad_inches=0)
        plt.close()
# Out:
# 29502

# %% [markdown]
# ## EKE video

# %%
def interp_u2_to_center(u):
    n,layers,ly,lx_p_1 = u.shape
    lx = lx_p_1 - 1
    u_center = np.zeros((n,layers,ly,lx))
    u_center[:,:,:,:] = (u[:,:,:,:-1] + u[:,:,:,1:])/2
    u_center[:,:,:,0] = (u[:,:,:,0] + u[:,:,:,-1])/2 # periodic
    u_center[:,:,:,-1] = (u[:,:,:,0] + u[:,:,:,-1])/2 # periodic
    
    return u_center
    
def interp_v2_to_center(v):
    n,layers,ly_p_1,lx = v.shape
    ly = ly_p_1 - 1
    v_center = np.zeros((n,layers,ly,lx))
    v_center[:,:,:,:] = (v[:,:,:-1,:] + v[:,:,1:,:])/2
    
    return v_center

# %%
st = xr.open_dataset('run13/static.nc', decode_times=False)

area_u = st.area_u.values.astype(float) # m^2
area_v = st.area_v.values.astype(float) # m^2
area_t = st.area_t.values.astype(float) # m^2
H = st.depth_ocean.values.astype(float) # m

# %%
xh = st.xh.values
yh = st.yh.values

grid = Grid(st, coords={'X': {'center': 'xh', 'outer': 'xq'},
                        'Y': {'center': 'yh', 'outer': 'yq'},
                        'Z': {'center': 'z_l', 'outer': 'z_i'} }, periodic=['X'])

run = [13,9,11,12]
plots = len(run)

end_time = 250-2000
while end_time < 27000:
    end_time = end_time + 2000
    print(end_time)
    filename = 'run13/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av1 = xr.open_dataset(filename, decode_times=False)
    filename = 'run9/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av2 = xr.open_dataset(filename, decode_times=False)
    filename = 'run11/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av3 = xr.open_dataset(filename, decode_times=False)
    filename = 'run12/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av4 = xr.open_dataset(filename, decode_times=False)
    EKE1 = (av1.KE.values.astype(float) - 0.5*(interp_u2_to_center(av1.u.values.astype(float)*av1.u.values.astype(float)*area_u) + interp_v2_to_center(av1.v.values.astype(float)*av1.v.values.astype(float)*area_v))/area_t)*av1.h.values.astype(float)/H
    EKE1 = EKE1.mean(axis=1)
    EKE2 = (av2.KE.values.astype(float) - 0.5*(interp_u2_to_center(av2.u.values.astype(float)*av2.u.values.astype(float)*area_u) + interp_v2_to_center(av2.v.values.astype(float)*av2.v.values.astype(float)*area_v))/area_t)*av2.h.values.astype(float)/H
    EKE2 = EKE2.mean(axis=1)
    EKE3 = (av3.KE.values.astype(float) - 0.5*(interp_u2_to_center(av3.u.values.astype(float)*av3.u.values.astype(float)*area_u) + interp_v2_to_center(av3.v.values.astype(float)*av3.v.values.astype(float)*area_v))/area_t)*av3.h.values.astype(float)/H
    EKE3 = EKE3.mean(axis=1)
    EKE4 = (av4.KE.values.astype(float) - 0.5*(interp_u2_to_center(av4.u.values.astype(float)*av4.u.values.astype(float)*area_u) + interp_v2_to_center(av4.v.values.astype(float)*av4.v.values.astype(float)*area_v))/area_t)*av4.h.values.astype(float)/H
    EKE4 = EKE4.mean(axis=1)
    time = av1.time
    for i in range(len(time)):
        vmin = min(np.nanmin(EKE1[i]),np.nanmin(EKE2[i]),np.nanmin(EKE3[i]),np.nanmin(EKE4[i]))
        vmax = max(np.nanmax(EKE1[i]),np.nanmax(EKE2[i]),np.nanmax(EKE3[i]),np.nanmax(EKE4[i]))
        plt.figure(figsize=(12,4))
        plt.suptitle('Time = %.1f days' %time[i])
        plt.subplot(1,plots,1)
        plt.pcolormesh(xh,yh,EKE1[i], cmap=cmocean.cm.matter_r)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.clim(vmin, vmax)
        plt.xlabel('longitude')
        plt.ylabel('latitude')
        plt.title('SARDOUNY75_ENERGY')
        plt.subplot(1,plots,2)
        plt.pcolormesh(xh,yh,EKE2[i], cmap=cmocean.cm.matter_r)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.clim(vmin, vmax)
        plt.xlabel('longitude')
        plt.title('ARAKAWA_HSU90')
        plt.subplot(1,plots,3)
        plt.pcolormesh(xh,yh,EKE3[i], cmap=cmocean.cm.matter_r)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.clim(vmin, vmax)
        plt.xlabel('longitude')
        plt.title('ARAKAWA_LAMB81')
        plt.subplot(1,plots,4)
        plt.pcolormesh(xh,yh,EKE4[i], cmap=cmocean.cm.matter_r)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.clim(vmin, vmax)
        plt.xlabel('longitude')
        plt.title('ARAKAWA_LAMB_BLEND')
        plt.colorbar(format='%.4f')
        save_name = 'EKE/fig_'+'{0:06}'.format(int(time[i]))+ '.png'
        plt.savefig(save_name, dpi=200,bbox_inches='tight',pad_inches=0)
        plt.close()
# Out:
# 250
# 2250
# 4250
# 6250
# 8250
# 10250
# 12250
# 14250
# 16250
# 18250
# 20250
# 22250
# 24250
# 26250
# 28250

# %% [markdown]
# ## Enstrophy video

# %%
end_time = 29502-500
while end_time < 29502:
    end_time = end_time + 500
    print(end_time)
    filename = 'run13/averages_'+'{0:08}'.format(end_time)+ '.nc'
    av1 = xr.open_dataset(filename, decode_times=False)
    filename = 'run9/averages_'+'{0:08}'.format(end_time)+ '.nc'
    av2 = xr.open_dataset(filename, decode_times=False)
    filename = 'run11/averages_'+'{0:08}'.format(end_time)+ '.nc'
    av3 = xr.open_dataset(filename, decode_times=False)
    filename = 'run12/averages_'+'{0:08}'.format(end_time)+ '.nc'
    av4 = xr.open_dataset(filename, decode_times=False)
    ens1 = av1.RV2.values[:,0]
    ens1 = ens1/86400
    ens2 = av2.RV2.values[:,0]
    ens2 = ens2/86400
    ens3 = av3.RV2.values[:,0]
    ens3 = ens3/86400
    ens4 = av4.RV2.values[:,0]
    ens4 = ens4/86400
    time = av1.time
    for i in range(len(time)): 
        plt.figure(figsize=(12,4))
        plt.suptitle('Time = %.1f days' %time[i])
        plt.subplot(1,plots,1)
        plt.pcolormesh(xq,yq,ens1[i], norm=colors.LogNorm(vmin=8e-15, vmax=np.nanmax(ens1[i])), cmap=cmocean.cm.deep)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.ylabel('latitude')
        plt.title('SARDOUNY75_ENERGY')
        plt.subplot(1,plots,2)
        plt.pcolormesh(xq,yq,ens2[i], norm=colors.LogNorm(vmin=8e-15, vmax=np.nanmax(ens1[i])), cmap=cmocean.cm.deep)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.title('ARAKAWA_HSU90')
        plt.subplot(1,plots,3)
        plt.pcolormesh(xq,yq,ens3[i], norm=colors.LogNorm(vmin=8e-15, vmax=np.nanmax(ens1[i])), cmap=cmocean.cm.deep)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.title('ARAKAWA_LAMB81')
        plt.subplot(1,plots,4)
        plt.pcolormesh(xq,yq,ens4[i], norm=colors.LogNorm(vmin=8e-15, vmax=np.nanmax(ens1[i])), cmap=cmocean.cm.deep)
        plt.gca().set_aspect('equal', adjustable='box')
        plt.xlabel('longitude')
        plt.title('ARAKAWA_LAMB_BLEND')
        plt.colorbar()
        save_name = 'Enstrophy/fig_'+'{0:06}'.format(int(time[i]))+ '.png'
        plt.savefig(save_name, dpi=200,bbox_inches='tight',pad_inches=0)
        plt.close()
# Out:
# 29502

# %% [markdown]
# ## ACC transport

# %%
acc1 = np.zeros((30000//500))
acc2 = np.zeros((30000//500))
acc3 = np.zeros((30000//500))
acc4 = np.zeros((30000//500))
time = np.arange(0,30000,500)

# %%
end_time = 250-2000
i=0-4
while end_time < 24250:
    i=i+4
    end_time = end_time + 2000
    print(end_time)
    filename = 'run13/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av1 = xr.open_dataset(filename, decode_times=False)
    filename = 'run9/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av2 = xr.open_dataset(filename, decode_times=False)
    filename = 'run11/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av3 = xr.open_dataset(filename, decode_times=False)
    filename = 'run12/longmean_'+'{0:08}'.format(end_time)+ '.nc'
    av4 = xr.open_dataset(filename, decode_times=False)
    acc1_temp = av1.uh[:,:,:161,0]
    acc2_temp = av2.uh[:,:,:161,0]
    acc3_temp = av3.uh[:,:,:161,0]
    acc4_temp = av4.uh[:,:,:161,0]
    acc1[i:(i+4)] = np.nansum(np.nansum(acc1_temp, axis=2),axis=1)
    acc2[i:(i+4)] = np.nansum(np.nansum(acc2_temp, axis=2),axis=1)
    acc3[i:(i+4)] = np.nansum(np.nansum(acc3_temp, axis=2),axis=1)
    acc4[i:(i+4)] = np.nansum(np.nansum(acc4_temp, axis=2),axis=1)
# Out:
# 250
# 2250
# 4250
# 6250
# 8250
# 10250
# 12250
# 14250
# 16250
# 18250
# 20250
# 22250
# 24250

# %%
plt.figure(figsize=(12,7))
plt.plot(time,acc1/1e6)
plt.plot([0],[0])
plt.plot(time,acc2/1e6)
plt.plot(time,acc3/1e6)
plt.plot(time,acc4/1e6)
plt.ylabel('ACC transport (Sv)')
plt.xlabel('time (days)')
plt.gca().legend(('SARDOUNY75_ENERGY','SARDOUNY75_ENSTRO','ARAKAWA_HSU90','ARAKAWA_LAMB81','ARAKAWA_LAMB_BLEND'))
plt.grid()
plt.axis((0,25000,0,275))
plt.savefig('ACC_transport.png', dpi=200,bbox_inches='tight',pad_inches=0)
